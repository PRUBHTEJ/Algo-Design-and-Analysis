# %%
import matplotlib.pyplot as plt

# %%
x1 = [10, 100, 1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000]

y1 = [1, 9, 796, 2986, 6400, 11624, 17946, 26001, 35419, 46273, 58779]

y2 =[ 1,11, 801, 3360, 6624,11812, 18157, 25642, 35054, 46013,58687]

plt.scatter(x, y1)

plt.scatter(x, y2)
